# %% [markdown]
# <a href="https://colab.research.google.com/github/kalitafaadya25/KKA-X-Semester-1-Kalita-a.f/blob/main/3_aplikasi_kalkulator_sederhana_kalita_A_F_x_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
panjang=int(input("masukkan panjang dari persegi panjang(cm):  "))
lebar=int(input("masukkan lebar dari persegi panjang(cm(:  "))
yg
luas=panjang*lebar
print(f"\nluas dari persegi panjang yaitu {luas} cm^2")
# Out:
# masukkan panjang dari persegi panjang(cm):  5
# masukkan lebar dari persegi panjang(cm(:  4
#
# luas dari persegi panjang yaitu 20 cm^2

# %% [markdown]
# #kalkulator menghitung volume bangun

# %%
jari_jari = int(input("Masukkan jari_jari dari bola (cm): "))

Luas = 4 * 22/7 * jari_jari**2

print(f"\nLuas dari bola yaitu {Luas} cm^2")
# Out:
# Masukkan jari_jari dari bola (cm): 7
#
# Luas dari bola yaitu 616.0 cm^2

# %%
jari_jari = int(input("Masukkan jari_jari dari bola (cm): "))

volume = 4/3 * 22/7 * jari_jari**3

print(f"\nVolume dari bola yaitu {volume} cm^3")
# Out:
# Masukkan jari_jari dari bola (cm): 30
#
# Volume dari bola yaitu 113142.85714285714 cm^3
