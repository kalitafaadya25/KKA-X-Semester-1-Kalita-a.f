# %% [markdown]
# <a href="https://colab.research.google.com/github/kalitafaadya25/KKA-X-Semester-1-Kalita-a.f/blob/main/Tipe_Variabel_Kalita_af_x_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Kalita AF
#
#
# Kelas: x.2
#
#
# No.absen:16

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("kalitafaadya.2025@gmail.com")
print("kalitafaadya.2025@gmail.com")
print("kalitafaadya.2025@gmail.com")
# Out:
# kalitafaadya.2025@gmail.com
# kalitafaadya.2025@gmail.com
# kalitafaadya.2025@gmail.com

# %%
email_user="kalitafaadya.2025@gmail.com"
print(email_user)
print(email_user)
print(email_user)
# Out:
# kalitafaadya.2025@gmail.com
# kalitafaadya.2025@gmail.com
# kalitafaadya.2025@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
#hanya boleh menggunakan huruf,angka,dan underscore
harga telur=15000
print(harga telur)
# Out:
#   File "/tmp/ipython-input-2891552818.py", line 2
#     harga telur=15000
#           ^
# SyntaxError: invalid syntax

# %%
hargatelur=15000
print(hargatelur)
# Out:
# 15000

# %%
#tidak boleh diawali oleh angka
1_nama_siswa="Ahmad Dhani"
print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-2983277451.py", line 2
#     1_nama_siswa="Ahmad Dhani"
#      ^
# SyntaxError: invalid decimal literal

# %%
#tidak boleh menggunakan kata kunci python
if=Handayani
print(if)
# Out:
#   File "/tmp/ipython-input-844705316.py", line 2
#     if=Handayani
#       ^
# SyntaxError: invalid syntax

# %%
If="Handayani"
print(If)
# Out:
# Handayani

# %%
print="Noor"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3315149700.py in <cell line: 0>()
#       1 print="Noor"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print="Noor"
print(Print)
# Out:
# Noor

# %%
#sensitif terhadap penulisan kapital
USIA=17
print(Usia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3829638130.py in <cell line: 0>()
#       1 #sensitif terhadap penulisan kapital
#       2 USIA=17
# ----> 3 print(Usia)
#
# NameError: name 'Usia' is not defined

# %%
print(USIA)
# Out:
# 17

# %%
_="fazel wardana"
print(_)
# Out:
# fazel wardana

# %%
_="lia wati"
print(_)
# Out:
# lia wati

# %% [markdown]
# #Assignment

# %%
#singe assignment
bb_fazel=55
bb_dani=60

print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
#multiple assignment
bb_fazel,bb_dani=55,60
print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
bb_fazel,bb_dani=55,60,70
print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-421746387.py in <cell line: 0>()
# ----> 1 bb_fazel,bb_dani=55,60,70
#       2 print(bb_dani)
#       3 print(bb_fazel)
#
# ValueError: too many values to unpack (expected 2)

# %%
nama_siswa_1,nama_siswa_2="deni","doni"
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# deni
# doni

# %%
bb_dani,bb_fazel,bb_adli=55,60
print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3284964846.py in <cell line: 0>()
# ----> 1 bb_dani,bb_fazel,bb_adli=55,60
#       2 print(bb_dani)
#       3 print(bb_fazel)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
#chain assignment
bb_hasbi=bb_dani=60
print(bb_hasbi)
print(bb_dani)
# Out:
# 60
# 60

# %%
print("shinta")
# Out:
# shinta

# %%
print("9+6")
# Out:
# 9+6

# %%
#operand disimpan di variabel
jumlah_hp_habibi=10
jumlah_hp_syauqi=6
print(jumlah_hp_habibi+jumlah_hp_syauqi)
# Out:
# 16

# %%
#hasil operasi di simpan ke variabel
total_hp=10+6
print(total_hp)
# Out:
# 16

# %%
#operand dan hasil operasi disimpan ke variabel
jumlah_hp_habibi=10
jumlah_hp_syauqi=6
total_hp=jumlah_hp_habibi+jumlah_hp_syauqi
print(total_hp)
# Out:
# 16

# %%
nama="andi"
print(nama)
# Out:
# andi

# %%
nama="Budi"
umur=15
kelas="9A"
print(nama
# Out:
# Budi
# 15
# 9A

# %%
berat_andi=berat_siti=berat_eko=45.5
print(berat_andi)
print(berat_siti)
print(berat_eko)
# Out:
# 45.5
# 45.5
# 45.5
